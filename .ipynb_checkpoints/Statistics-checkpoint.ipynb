# %%
import pandas as pd
import os
import requests

# %%
df = pd.read_csv("query.csv")

# %%
df.head(5)
# Out:
#                                      item                          itemLabel  \
# 0  http://www.wikidata.org/entity/Q204243                  St. Roch in Glory
# 1  http://www.wikidata.org/entity/Q389198                    Three Musicians
# 2  http://www.wikidata.org/entity/Q478271  Reply of the Zaporozhian Cossacks
# 3  http://www.wikidata.org/entity/Q587514                     The City Rises
# 4  http://www.wikidata.org/entity/Q600379                 Banks of the Marne
#
#                              depicts  \
# 0  http://www.wikidata.org/entity/Q5
# 1  http://www.wikidata.org/entity/Q5
# 2  http://www.wikidata.org/entity/Q5
# 3  http://www.wikidata.org/entity/Q5
# 4  http://www.wikidata.org/entity/Q5
#
#                                                image                  year  \
# 0  http://commons.wikimedia.org/wiki/Special:File...  1564-01-01T00:00:00Z
# 1  http://commons.wikimedia.org/wiki/Special:File...  1617-01-01T00:00:00Z
# 2  http://commons.wikimedia.org/wiki/Special:File...  1891-01-01T00:00:00Z
# 3  http://commons.wikimedia.org/wiki/Special:File...  1910-01-01T00:00:00Z
# 4  http://commons.wikimedia.org/wiki/Special:File...  1888-01-01T00:00:00Z
#
#                                    author
# 0    http://www.wikidata.org/entity/Q9319
# 1     http://www.wikidata.org/entity/Q297
# 2  http://www.wikidata.org/entity/Q172911
# 3  http://www.wikidata.org/entity/Q152797
# 4   http://www.wikidata.org/entity/Q35548

# %%
top_depict = df['depicts'].value_counts().rename_axis('unique_depicts').reset_index(name='counts').head(10)

# %%
df['author'].value_counts().head(10)
# Out:
# http://www.wikidata.org/entity/Q4233718    4000
# http://www.wikidata.org/entity/Q5582       1726
# http://www.wikidata.org/entity/Q134741     1564
# http://www.wikidata.org/entity/Q5598       1434
# http://www.wikidata.org/entity/Q5599       1371
# http://www.wikidata.org/entity/Q483992     1216
# http://www.wikidata.org/entity/Q47551      1120
# http://www.wikidata.org/entity/Q296        1081
# http://www.wikidata.org/entity/Q213612     1067
# http://www.wikidata.org/entity/Q212499     1040
# Name: author, dtype: int64

# %%
cat_count = int(top_depict['counts'].tail(1))
cat_count = 1
dirname = "" #os.path.dirname(__file__)

for depict in top_depict['unique_depicts']:
    cat_df = df.loc[df['depicts'] == depict].head(cat_count)
    for index, row in cat_df.iterrows():
        file_name = os.path.join(dirname, depict, row["item"].split('.')[-1])
        url = row["image"]
        extension = url.rsplit('.', 1)[1]
        print(file_name)
#         if not os.path.isfile(file_name):
#             r = requests.get(url, allow_redirects=True)
#             open(filename, 'wb').write(r.content)
# Out:
#                                         item                      itemLabel  \
# 4433  http://www.wikidata.org/entity/Q745098  Rest on the Flight into Egypt
#
#                                   depicts  \
# 4433  http://www.wikidata.org/entity/Q467
#
#                                                   image                  year  \
# 4433  http://commons.wikimedia.org/wiki/Special:File...  1597-01-01T00:00:00Z
#
#                                      author
# 4433  http://www.wikidata.org/entity/Q42207
#                                           item         itemLabel  \
# 26974  http://www.wikidata.org/entity/Q3224275  The Slave Market
#
#                                     depicts  \
# 26974  http://www.wikidata.org/entity/Q8441
#
#                                                    image  \
# 26974  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                  author
# 26974  1866-01-01T00:00:00Z  http://www.wikidata.org/entity/Q212499
#                                          item         itemLabel  \
# 2924  http://www.wikidata.org/entity/Q3618173  The Annunciation
#
#                                   depicts  \
# 2924  http://www.wikidata.org/entity/Q345
#
#                                                   image                  year  \
# 2924  http://commons.wikimedia.org/wiki/Special:File...  1500-01-01T00:00:00Z
#
#                                     author
# 2924  http://www.wikidata.org/entity/Q8453
#                                           item        itemLabel  \
# 12549  http://www.wikidata.org/entity/Q1713754  Nymph and Satyr
#
#                                    depicts  \
# 12549  http://www.wikidata.org/entity/Q527
#
#                                                    image  \
# 12549  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                  author
# 12549  1716-01-01T00:00:00Z  http://www.wikidata.org/entity/Q183221
#                                           item         itemLabel  \
# 34430  http://www.wikidata.org/entity/Q4009567  Venus and Adonis
#
#                                      depicts  \
# 34430  http://www.wikidata.org/entity/Q10884
#
#                                                    image  \
# 34430  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                   author
# 34430  1555-01-01T00:00:00Z  http://www.wikidata.org/entity/Q4233718
#                                            item  \
# 24844  http://www.wikidata.org/entity/Q17276263
#
#                               itemLabel                               depicts  \
# 24844  Italianate Landscape with Cattle  http://www.wikidata.org/entity/Q8074
#
#                                                    image  \
# 24844  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                  author
# 24844  1631-01-01T00:00:00Z  http://www.wikidata.org/entity/Q719666
#                                           item  \
# 18248  http://www.wikidata.org/entity/Q3842573
#
#                                                itemLabel  \
# 18248  Madonna and Child with St Francis and St John ...
#
#                                     depicts  \
# 18248  http://www.wikidata.org/entity/Q3010
#
#                                                    image  \
# 18248  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                  author
# 18248  1310-01-01T00:00:00Z  http://www.wikidata.org/entity/Q309635
#                                           item              itemLabel  \
# 90171  http://www.wikidata.org/entity/Q1092638  Madonna di Senigallia
#
#                                       depicts  \
# 90171  http://www.wikidata.org/entity/Q942467
#
#                                                    image  \
# 90171  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                author
# 90171  1470-01-01T00:00:00Z  http://www.wikidata.org/entity/Q5822
#                                          item                  itemLabel  \
# 1726  http://www.wikidata.org/entity/Q3697599  Christ and Mary Magdalene
#
#                                   depicts  \
# 1726  http://www.wikidata.org/entity/Q302
#
#                                                   image                  year  \
# 1726  http://commons.wikimedia.org/wiki/Special:File...  1617-01-01T00:00:00Z
#
#                                     author
# 1726  http://www.wikidata.org/entity/Q5599
#                                           item                    itemLabel  \
# 93724  http://www.wikidata.org/entity/Q3399458  Portrait of Pierre Sériziat
#
#                                        depicts  \
# 93724  http://www.wikidata.org/entity/Q1144593
#
#                                                    image  \
# 93724  http://commons.wikimedia.org/wiki/Special:File...
#
#                        year                                 author
# 93724  1795-01-01T00:00:00Z  http://www.wikidata.org/entity/Q83155
